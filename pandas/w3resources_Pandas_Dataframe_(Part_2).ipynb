# %% [markdown]
# 54. Write a Pandas program to convert a given list of lists into a Dataframe.

# %%
import pandas as pd
import numpy as np

# %%
my_lists = [['col1', 'col2'], [2, 4], [1, 3]]

headers = my_lists.pop(0)

df = pd.DataFrame(my_lists, columns=headers)
df
# Out:
#    col1  col2
# 0     2     4
# 1     1     3

# %% [markdown]
# 55. Write a Pandas program to group by the first column and get second column as lists in rows.

# %%
df = pd.DataFrame( {'col1':['C1','C1','C2','C2','C2','C3','C2'], 'col2':[1,2,3,3,4,6,5]})
print(df)
df.groupby('col1')['col2'].apply(list)
# Out:
#   col1  col2
# 0   C1     1
# 1   C1     2
# 2   C2     3
# 3   C2     3
# 4   C2     4
# 5   C3     6
# 6   C2     5
# col1
# C1          [1, 2]
# C2    [3, 3, 4, 5]
# C3             [6]
# Name: col2, dtype: object

# %% [markdown]
# 56. Write a Pandas program to get column index from column name of a given DataFrame.

# %%
d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5], 'col3': [7, 8, 12, 1, 11]}
df = pd.DataFrame(data=d)
print(df)
df.columns.get_loc('col2')
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
# 1

# %% [markdown]
# 57. Write a Pandas program to count number of columns of a DataFrame.

# %%
len(df.columns)
# Out:
# 3

# %% [markdown]
# 58. Write a Pandas program to select all columns, except one given column in a DataFrame.

# %%
df.loc[:, df.columns != 'col2']
# Out:
#    col1  col3
# 0     1     7
# 1     2     8
# 2     3    12
# 3     4     1
# 4     7    11

# %% [markdown]
# 59. Write a Pandas program to get first n records of a DataFrame.

# %%
df.head(2)
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8

# %% [markdown]
# 60. Write a Pandas program to get last n records of a DataFrame.

# %%
df.tail(2)
# Out:
#    col1  col2  col3
# 3     4     9     1
# 4     7     5    11

# %% [markdown]
# 61. Write a Pandas program to get topmost n records within each group of a DataFrame.

# %%
print("col1\n", df.nlargest(3, 'col1'))
print("col2\n", df.nlargest(3, 'col2'))
print("col3\n", df.nlargest(3, 'col3'))
# Out:
# col1
#     col1  col2  col3
# 4     7     5    11
# 3     4     9     1
# 2     3     6    12
# col2
#     col1  col2  col3
# 3     4     9     1
# 2     3     6    12
# 1     2     5     8
# col3
#     col1  col2  col3
# 2     3     6    12
# 4     7     5    11
# 1     2     5     8

# %% [markdown]
# 62. Write a Pandas program to remove first n rows of a given DataFrame.

# %%
print(df)
df.iloc[3:, ]   #first 3 rows removing
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
#    col1  col2  col3
# 3     4     9     1
# 4     7     5    11

# %% [markdown]
# 63. Write a Pandas program to remove last n rows of a given DataFrame.

# %%
df.iloc[:3 ]
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12

# %% [markdown]
# 64. Write a Pandas program to add a prefix or suffix to all columns of a given DataFrame.
# Sample Output:

# %%
print(df.add_prefix('A_'))
print(df.add_suffix('_1'))
# Out:
#    A_col1  A_col2  A_col3
# 0       1       4       7
# 1       2       5       8
# 2       3       6      12
# 3       4       9       1
# 4       7       5      11
#    col1_1  col2_1  col3_1
# 0       1       4       7
# 1       2       5       8
# 2       3       6      12
# 3       4       9       1
# 4       7       5      11

# %% [markdown]
# 66. Write a Pandas program to select columns by data type of a given DataFrame.
#
# i. Select numerical columns
#
# ii. Select string columns

# %%
df = pd.DataFrame({
    'Name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Syed Wharton'],
    'Date_Of_Birth': ['17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'Age': [18.5, 21.2, 22.5, 22, 23]
})

print(df.select_dtypes(include='number'))
print(df.select_dtypes(include='object'))
# Out:
#     Age
# 0  18.5
# 1  21.2
# 2  22.5
# 3  22.0
# 4  23.0
#              Name Date_Of_Birth
# 0  Alberto Franco    17/05/2002
# 1    Gino Mcneill    16/02/1999
# 2     Ryan Parkes    25/09/1998
# 3    Eesha Hinton    11/05/2002
# 4    Syed Wharton    15/09/1997

# %% [markdown]
# 67. Write a Pandas program to split a given DataFrame into two random subsets.

# %%
df_1 = df.sample(frac=0.6)
df_2 = df.drop(df_1.index)
print(df)
print(df_1)
print(df_2)
# Out:
#              name date_of_birth   age
# 0  Alberto Franco    17/05/2002  18.5
# 1    Gino Mcneill    16/02/1999  21.2
# 2     Ryan Parkes    25/09/1998  22.5
# 3    Eesha Hinton    11/05/2002  22.0
# 4    Syed Wharton    15/09/1997  23.0
#              name date_of_birth   age
# 2     Ryan Parkes    25/09/1998  22.5
# 0  Alberto Franco    17/05/2002  18.5
# 3    Eesha Hinton    11/05/2002  22.0
#            name date_of_birth   age
# 1  Gino Mcneill    16/02/1999  21.2
# 4  Syed Wharton    15/09/1997  23.0

# %% [markdown]
# 68. Write a Pandas program to rename all columns with the same pattern of a given DataFrame.
#
# Remove trailing (at the end) whitesapce and convert to lowercase of the columns name

# %%
print(df)
df.columns= df.columns.str.lower().str.rstrip()
df
# Out:
#              name date_of_birth   age
# 0  Alberto Franco    17/05/2002  18.5
# 1    Gino Mcneill    16/02/1999  21.2
# 2     Ryan Parkes    25/09/1998  22.5
# 3    Eesha Hinton    11/05/2002  22.0
# 4    Syed Wharton    15/09/1997  23.0
#              name date_of_birth   age
# 0  Alberto Franco    17/05/2002  18.5
# 1    Gino Mcneill    16/02/1999  21.2
# 2     Ryan Parkes    25/09/1998  22.5
# 3    Eesha Hinton    11/05/2002  22.0
# 4    Syed Wharton    15/09/1997  23.0

# %% [markdown]
# 69. Write a Pandas program to merge datasets and check uniqueness.

# %%
df = pd.DataFrame({
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Syed Wharton', 'Kierra Gentry'],
      'age': [18, 22, 85, 50, 80, 5]
})

df['age_group'] = pd.cut(df['age'], bins=[0, 18, 65, 99], labels=['kids', 'adults','elderly'])
df
# Out:
#              name  age age_group
# 0  Alberto Franco   18      kids
# 1    Gino Mcneill   22    adults
# 2     Ryan Parkes   85   elderly
# 3    Eesha Hinton   50    adults
# 4    Syed Wharton   80   elderly
# 5   Kierra Gentry    5      kids

# %% [markdown]
# 70. Write a Pandas program to display memory usage of a given DataFrame and every column of the DataFrame.

# %%
print(df.info(memory_usage=True))
print(df.memory_usage(deep=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       6 non-null      object
#  1   age        6 non-null      int64
#  2   age_group  6 non-null      category
# dtypes: category(1), int64(1), object(1)
# memory usage: 362.0+ bytes
# None
# Index        128
# name         416
# age           48
# age_group    302
# dtype: int64

# %% [markdown]
# 72. Write a Pandas program to combine many given series to create a DataFrame.

# %%
sr1 = pd.Series(['php', 'python', 'java', 'c#', 'c++'])
sr2 = pd.Series([1, 2, 3, 4, 5])

pd_concat=pd.concat([sr1,sr2])
print(pd_concat, type(pd_concat))

df=pd.DataFrame({'col':sr1, 'col2': sr2})
df
# Out:
# 0       php
# 1    python
# 2      java
# 3        c#
# 4       c++
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
# dtype: object <class 'pandas.core.series.Series'>
#       col  col2
# 0     php     1
# 1  python     2
# 2    java     3
# 3      c#     4
# 4     c++     5

# %% [markdown]
# 73. Write a Pandas program to create DataFrames that contains random values, contains missing values, contains datetime values and contains mixed values.

# %%
print("DataFrame: Contains random values:")
df1=pd.util.testing.makeDataFrame()
print(df1)

print("\nDataFrame: Contains missing values:")
df2 = pd.util.testing.makeMissingDataframe()
print(df2)

print("\nDataFrame: Contains datetime values:")
df3 = pd.util.testing.makeTimeDataFrame()
print(df3)

print("\nDataFrame: Contains mixed values:")
df4 = pd.util.testing.makeMixedDataFrame() # contains mixed values
print(df4)
# Out:
# DataFrame: Contains random values:
#                    A         B         C         D
# g2w2k5lkN4  0.990978  1.147603 -0.937170  0.062915
# icPofbsN0J  0.449209 -1.672397 -0.414038 -0.058902
# GaD7f9UQsi -0.857309  2.429895  0.580226  1.712999
# cxWjFi5HhK  0.356898 -0.706155 -0.733898  0.518853
# PfgdPTwhx4 -1.573139 -1.701221 -1.147446 -0.012842
# uzwn0Umxu8 -0.020089 -1.050565 -0.161197 -1.568189
# zgG0jLNLJQ  0.750711  0.551385 -0.502963 -1.426735
# 2xlolEYWo4  0.442157  1.039735  0.240618  1.026328
# nDGfNvIpwj -0.024477 -0.231739 -0.312654  0.871990
# yuabcLCOgh -1.104262  0.586328  0.800092 -1.017764
# QaitMovhY9  0.650951 -0.230459 -0.399639 -0.364238
# SVc8AJshwt  0.117761  0.380208  0.033104  1.820709
# HN09M1D6eQ  0.050297  0.235640 -0.274694 -2.604752
# mwYNeEdMaV -0.915902 -1.551277  1.076718 -0.513451
# EmuivPNGbd  0.932015  1.567803  1.448134  0.572803
# NXL8WMSnol -0.755899 -1.806959 -1.750368 -0.965138
# vX5GWvrQ0M  1.075972 -1.308090  0.487182 -0.475362
# JDWTFfOECd  0.098264 -0.760205  0.429141  2.249866
# BBprLPtra6  0.046504 -1.312956  1.257268  1.149201
# Bcq30nFHDv  0.406928 -0.329747  0.697111 -0.084480
# vbRGGhGdVa  1.301325 -0.398346  0.466146 -0.405313
# fdaNS4DjIi  0.658214 -1.148664  0.213437 -0.160403
# DT9pRxPLGT  1.729115 -0.031154  0.879270 -0.272882
# arcv8pMFBn -2.174923  1.537282  0.808623  0.185066
# yLJXuoh1qB  0.977277 -0.790955 -1.066735  0.355779
# pXPqN3wqI3  0.291936 -1.802934 -0.635360 -1.138838
# BfGN5BkrDB  0.622796 -0.263764 -0.024414  0.313391
# qRQqTgkyLR  0.126488  1.091975 -0.509954 -1.122517
# Dy2SGvNqfU  1.326775 -0.867382 -0.903719  0.386624
# mioBbtXq3A -0.311347 -0.419538 -0.033202 -0.153802
#
# DataFrame: Contains missing values:
#                    A         B         C         D
# qwxUSo5icB  1.800512 -0.304682  1.092752  0.404542
# TE9cmYFrjP  0.314560 -1.497300  0.366210  0.003456
# ALHJiQhuUN       NaN -0.366986 -0.031395 -0.063715
# i1WA8aXJXx -0.741704 -0.311810       NaN  0.745613
# 2iaRLysmIo  1.443286 -0.882153  1.309128  0.960709
# b8zAou5Zs0  0.259780  1.450171 -0.126767  3.127655
# HWIvScHLaX -1.217010 -0.199069 -0.217602       NaN
# 1zYOrqWda6 -0.390942 -0.348676  0.710702  1.338772
# 7Nn7CHveeH  0.326623  0.263308 -1.600229  1.501949
# 08IY2HpIgM  0.587587 -0.383008  0.634819 -1.297573
# f6R5uECdcM       NaN       NaN -1.182981  1.240366
# DUBkcKVd5g -0.168362  0.522576  0.618939 -1.611232
# spVhPdjwyW       NaN  0.878223 -0.299072       NaN
# 1Ke6Z3BuP1 -1.010316  1.240932 -1.132315       NaN
# VUxYS3mic4  0.493244 -2.005374  0.217782 -0.695592
# leB2am8EhN -0.125088 -0.961815  0.873991 -0.988776
# lXtPQSZyCL  0.053960  0.413967  0.404227  1.514506
# 2wivWn0LBq -0.434786 -0.439787 -0.701103 -0.280269
# skzFv6pfO9 -1.653466 -0.733935  0.468475 -0.253953
# HGrC7x3Myq -0.405943 -1.288921  0.494947 -1.185878
# KzNopUIMzN -0.719711 -0.438384  0.722801 -2.024245
# FYy9sZNsmV  0.028966 -1.189346  0.832626  0.212358
# I5WDriMTbK  0.827310  0.070481 -1.510672  0.027927
# 60TeWpep8o  0.467615  0.602250  0.505853  0.184175
# qckxtpjFgn -1.203820 -2.674375  1.870371 -0.158194
# Cu9wA9zEBg -1.187299 -0.014142       NaN  0.546200
# NzPkGJVoJM -0.699974       NaN -1.900506 -0.442794
# oqHFMdP2ua       NaN  0.704306 -0.816921 -1.079163
# tjP2I1wUF6  2.121084  0.048414       NaN  0.258517
# GKSt4QKYk0 -0.704996  1.778713  0.294577 -0.069251
#
# DataFrame: Contains datetime values:
#                    A         B         C         D
# 2000-01-03 -0.376541  0.089471 -1.619876  0.005266
# 2000-01-04 -0.931820  0.475488  1.669216 -1.083382
# 2000-01-05  0.351040 -0.147497  0.015861 -2.001913
# 2000-01-06  0.247848  0.230617  1.599421  0.881122
# 2000-01-07  0.843096 -0.262606  0.018314 -0.376274
# 2000-01-10 -0.956909  0.091910  1.294587  2.307236
# 2000-01-11 -0.773334 -0.439227  0.982338  1.306709
# 2000-01-12 -0.508754 -1.104568  0.197649  0.535915
# 2000-01-13  0.292375 -2.114286  1.790452 -0.548620
# 2000-01-14  0.099057  0.159325 -0.801009 -0.209439
# 2000-01-17  0.789684 -2.139162 -1.615480  2.220322
# 2000-01-18  0.912814  1.852744  0.796173 -0.276925
# 2000-01-19 -1.416365 -1.177145 -0.528837 -0.512087
# 2000-01-20 -2.048022  0.849229 -0.478086 -0.032019
# 2000-01-21 -2.606062  0.762262  0.322662  1.505352
# 2000-01-24 -0.891148 -2.149400  0.818090  1.464980
# 2000-01-25 -1.798300 -1.234512  1.075052  0.737226
# 2000-01-26 -0.804038 -0.488698 -0.489990  0.108584
# 2000-01-27  2.028596  1.232215  0.576550 -0.320431
# 2000-01-28 -0.391363 -3.622006 -1.767318 -1.106787
# 2000-01-31  2.069555  0.714914 -2.266475 -1.183817
# 2000-02-01  0.292464 -0.407001 -1.909479  1.055912
# 2000-02-02 -0.607621  0.945304 -0.636614 -0.394686
# 2000-02-03  0.046935  1.754926 -0.670616  0.814433
# 2000-02-04 -0.681798 -0.055137 -0.351518 -0.453177
# 2000-02-07  0.858602 -0.109309  0.133554  1.911800
# 2000-02-08  0.529615 -0.630287  1.013475  0.002779
# 2000-02-09  0.294059  0.442498 -1.661913 -0.946910
# 2000-02-10  0.393104  1.188110  0.304476  0.753484
# 2000-02-11 -0.993306  0.225273  1.457457 -1.147709
#
# DataFrame: Contains mixed values:
#      A    B     C          D
# 0  0.0  0.0  foo1 2009-01-01
# 1  1.0  1.0  foo2 2009-01-02
# 2  2.0  0.0  foo3 2009-01-05
# 3  3.0  1.0  foo4 2009-01-06
# 4  4.0  0.0  foo5 2009-01-07

# %% [markdown]
# 74. Write a Pandas program to fill missing values in time series data.
#
# From Wikipedia , in the mathematical field of numerical analysis, interpolation is a type of estimation, a method of constructing new data points within the range of a discrete set of known data points.

# %%
import pandas as pd
import numpy as np
sdata = {"c1":[120, 130 ,140, 150, np.nan, 170], "c2":[7, np.nan, 10, np.nan, 5.5, 16.5]}
df = pd.DataFrame(sdata)
df.index = pd.util.testing.makeDateIndex()[0:6]
print("Original DataFrame:")
print(df)
print("\nDataFrame after interpolate:")
print(df.interpolate())
# Out:
# Original DataFrame:
#                c1    c2
# 2000-01-03  120.0   7.0
# 2000-01-04  130.0   NaN
# 2000-01-05  140.0  10.0
# 2000-01-06  150.0   NaN
# 2000-01-07    NaN   5.5
# 2000-01-10  170.0  16.5
#
# DataFrame after interpolate:
#                c1     c2
# 2000-01-03  120.0   7.00
# 2000-01-04  130.0   8.50
# 2000-01-05  140.0  10.00
# 2000-01-06  150.0   7.75
# 2000-01-07  160.0   5.50
# 2000-01-10  170.0  16.50

# %% [markdown]
# 75. Write a Pandas program to use a local variable within a query.

# %%
import pandas as pd
df = pd.DataFrame({'W':[68,75,86,80,66],'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]});
print("Original DataFrame")
print(df)
maxx = df["W"].max()
print("\nValues which are less than maximum value of 'W' column")
print(df.query("W < @maxx"))
# Out:
# Original DataFrame
#     W   X   Y   Z
# 0  68  78  84  86
# 1  75  85  94  97
# 2  86  96  89  96
# 3  80  80  83  72
# 4  66  86  86  83
#
# Values which are less than maximum value of 'W' column
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-5ccaddf46d1d> in <cell line: 7>()
#       5 maxx = df["W"].max()
#       6 print("\nValues which are less than maximum value of 'W' column")
# ----> 7 print(df.query("W < @maxx"))
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4472         kwargs["level"] = kwargs.pop("level", 0) + 2
#    4473         kwargs["target"] = None
# -> 4474         res = self.eval(expr, **kwargs)
#    4475
#    4476         try:
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    4610         kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
#    4611
# -> 4612         return _eval(expr, inplace=inplace, **kwargs)
#    4613
#    4614     def select_dtypes(self, include=None, exclude=None) -> DataFrame:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     356         eng = ENGINES[engine]
#     357         eng_inst = eng(parsed_expr)
# --> 358         ret = eng_inst.evaluate()
#     359
#     360         if parsed_expr.assigner is None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/engines.py in evaluate(self)
#      79
#      80         # make sure no names in resolvers and locals/globals clash
# ---> 81         res = self._evaluate()
#      82         return reconstruct_object(
#      83             self.result_type, res, self.aligned_axes, self.expr.terms.return_type
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/engines.py in _evaluate(self)
#     120         scope = env.full_scope
#     121         _check_ne_builtin_clash(self.expr)
# --> 122         return ne.evaluate(s, local_dict=scope)
#     123
#     124
#
# /usr/local/lib/python3.10/dist-packages/numexpr/necompiler.py in evaluate(ex, local_dict, global_dict, out, order, casting, _frame_depth, **kwargs)
#     941         return re_evaluate(local_dict=local_dict, _frame_depth=_frame_depth)
#     942     else:
# --> 943         raise e
#     944
#     945 def re_evaluate(local_dict: Optional[Dict] = None,
#
# /usr/local/lib/python3.10/dist-packages/numexpr/necompiler.py in validate(ex, local_dict, global_dict, out, order, casting, _frame_depth, **kwargs)
#     849         expr_key = (ex, tuple(sorted(context.items())))
#     850         if expr_key not in _names_cache:
# --> 851             _names_cache[expr_key] = getExprNames(ex, context)
#     852         names, ex_uses_vml = _names_cache[expr_key]
#     853         arguments = getArguments(names, local_dict, global_dict, _frame_depth=_frame_depth)
#
# /usr/local/lib/python3.10/dist-packages/numexpr/necompiler.py in getExprNames(text, context)
#     712
#     713 def getExprNames(text, context):
# --> 714     ex = stringToExpression(text, {}, context)
#     715     ast = expressionToAST(ex)
#     716     input_order = getInputOrder(ast, None)
#
# /usr/local/lib/python3.10/dist-packages/numexpr/necompiler.py in stringToExpression(s, types, context)
#     272     no_whitespace = re.sub(r'\s+', '', s)
#     273     if _forbidden_re.search(no_whitespace) is not None:
# --> 274         raise ValueError(f'Expression {s} has forbidden control characters.')
#     275
#     276     old_ctx = expressions._context.get_current_context()
#
# ValueError: Expression (W) < (__pd_eval_local_maxx) has forbidden control characters.

# %% [markdown]
# 77. Write a Pandas program to get the numeric representation of an array by identifying distinct values of a given column of a DataFrame.

# %%
df = pd.DataFrame({
    'Name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill'],
    'Date_Of_Birth ': ['17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'Age': [18.5, 21.2, 22.5, 22, 23]
})
print("Original DataFrame:")
print(df)

label1, unique1 = pd.factorize(df['Name'])
print(label1, unique1 )
# Out:
# Original DataFrame:
#              Name Date_Of_Birth    Age
# 0  Alberto Franco     17/05/2002  18.5
# 1    Gino Mcneill     16/02/1999  21.2
# 2     Ryan Parkes     25/09/1998  22.5
# 3    Eesha Hinton     11/05/2002  22.0
# 4    Gino Mcneill     15/09/1997  23.0
# [0 1 2 3 1] Index(['Alberto Franco', 'Gino Mcneill', 'Ryan Parkes', 'Eesha Hinton'], dtype='object')

# %% [markdown]
# 78. Write a Pandas program to replace the current value in a dataframe column based on last largest value. If the current value is less than last largest value replaces the value with 0.

# %%
df1=pd.DataFrame({'rnum':[23, 21, 27, 22, 34, 33, 34, 31, 25, 22, 34, 19, 31, 32, 19]})
print("Original DataFrame:")
# print(df1)
df1['cummax']=df1.rnum.cummax()

df1['rnum_1']=df1.rnum.where(df1.rnum.eq(df1.rnum.cummax()), 0)
print(df1)
# Out:
# Original DataFrame:
#     rnum  cummax  rnum_1
# 0     23      23      23
# 1     21      23       0
# 2     27      27      27
# 3     22      27       0
# 4     34      34      34
# 5     33      34       0
# 6     34      34      34
# 7     31      34       0
# 8     25      34       0
# 9     22      34       0
# 10    34      34      34
# 11    19      34       0
# 12    31      34       0
# 13    32      34       0
# 14    19      34       0

# %% [markdown]
# 79. Write a Pandas program to create a DataFrame from the clipboard (data from an Excel spreadsheet or a Google Sheet).

# %%
df = pd.read_clipboard()
df
# Out:
# ---------------------------------------------------------------------------
# PyperclipException                        Traceback (most recent call last)
# <ipython-input-62-773f8617e89a> in <cell line: 1>()
# ----> 1 df = pd.read_clipboard()
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/clipboards.py in read_clipboard(sep, **kwargs)
#      43     from pandas.io.parsers import read_csv
#      44
# ---> 45     text = clipboard_get()
#      46
#      47     # Try to decode (if needed, as "text" might already be a string here).
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/clipboard/__init__.py in lazy_load_stub_paste()
#     659     global copy, paste
#     660     copy, paste = determine_clipboard()
# --> 661     return paste()
#     662
#     663
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/clipboard/__init__.py in __call__(self, *args, **kwargs)
#     297     class ClipboardUnavailable:
#     298         def __call__(self, *args, **kwargs):
# --> 299             raise PyperclipException(EXCEPT_MSG)
#     300
#     301         def __bool__(self) -> bool:
#
# PyperclipException:
#     Pyperclip could not find a copy/paste mechanism for your system.
#     For more information, please visit
#     https://pyperclip.readthedocs.io/en/latest/#not-implemented-error

# %% [markdown]
# 80. Write a Pandas program to check for inequality of two given DataFrames.

# %%
df1 = pd.DataFrame({'W':[68,75,86,80,None],'X':[78,85,None,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]});
df2 = pd.DataFrame({'W':[78,75,86,80,None],'X':[78,85,96,80,76], 'Y':[84,84,89,83,86],'Z':[86,97,96,72,83]});
print("Original DataFrames:")
print(df1)
print(df2)

df1.ne(df2)
# Out:
# Original DataFrames:
#       W     X   Y   Z
# 0  68.0  78.0  84  86
# 1  75.0  85.0  94  97
# 2  86.0   NaN  89  96
# 3  80.0  80.0  83  72
# 4   NaN  86.0  86  83
#       W   X   Y   Z
# 0  78.0  78  84  86
# 1  75.0  85  84  97
# 2  86.0  96  89  96
# 3  80.0  80  83  72
# 4   NaN  76  86  83
#        W      X      Y      Z
# 0   True  False  False  False
# 1  False  False   True  False
# 2  False   True  False  False
# 3  False  False  False  False
# 4   True   True  False  False

# %% [markdown]
# 81. Write a Pandas program to get lowest n records within each group of a given DataFrame.

# %%
d = {'col1': [1, 2, 3, 4, 7, 11], 'col2': [4, 5, 6, 9, 5, 0], 'col3': [7, 5, 8, 12, 1,11]}
df = pd.DataFrame(data=d)

df1=df.nsmallest(3, 'col1')
df2=df.nsmallest(3, 'col2')
df3=df.nsmallest(3, 'col3')

print(df1,'\n', df2,'\n',df3)
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8
#     col1  col2  col3
# 5    11     0    11
# 0     1     4     7
# 1     2     5     5
#     col1  col2  col3
# 4     7     5     1
# 1     2     5     5
# 0     1     4     7

# %% [markdown]
# ###Series

# %% [markdown]
# Write a Pandas program to display most frequent value in a given series and replace everything else as ‘Other’ in the series.

# %%
num_series = pd.Series(np.random.randint(1,5,(15)))
print(num_series)
print(num_series.value_counts())
num_series[~num_series.isin(num_series.value_counts().index[:2])]='others'
num_series
# Out:
# 0     2
# 1     1
# 2     3
# 3     4
# 4     4
# 5     3
# 6     1
# 7     3
# 8     3
# 9     1
# 10    1
# 11    4
# 12    2
# 13    2
# 14    3
# dtype: int64
# 3    5
# 1    4
# 2    3
# 4    3
# dtype: int64
# 0     others
# 1          1
# 2          3
# 3     others
# 4     others
# 5          3
# 6          1
# 7          3
# 8          3
# 9          1
# 10         1
# 11    others
# 12    others
# 13    others
# 14         3
# dtype: object
